# %%
import gymnasium as gym
from stable_baselines3 import DQN
env = gym.make("CartPole-v1")


model = DQN(
    "MlpPolicy",
    env,
    learning_rate=5e-4,
    buffer_size=100_000,
    exploration_final_eps=0.01,
    exploration_fraction=0.1,
    target_update_interval=1000,
    train_freq=4,
    gradient_steps=1,
    verbose=1,
)


model.learn(total_timesteps=500_000)
model.save("dqn_cartpole")

env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11742    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 709      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 148      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.42     |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 946      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 300      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.9     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1071     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 431      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0583   |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1115     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 507      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0269   |
# |    n_updates        | 101      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1160     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 592      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00935  |
# |    n_updates        | 122      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1181     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 653      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1215     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 758      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00429  |
# |    n_updates        | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1238     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 861      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00241  |
# |    n_updates        | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 989      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00384  |
# |    n_updates        | 222      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1100     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0284   |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1290     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1167     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0135   |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1299     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1245     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0158   |
# |    n_updates        | 286      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1308     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1309     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0226   |
# |    n_updates        | 302      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1327     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1427     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0168   |
# |    n_updates        | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1329     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1493     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00354  |
# |    n_updates        | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1339     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1576     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0228   |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1348     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1674     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00288  |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1358     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1755     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0224   |
# |    n_updates        | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1363     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1816     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0302   |
# |    n_updates        | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1367     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1871     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0452   |
# |    n_updates        | 442      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1370     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1946     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00425  |
# |    n_updates        | 461      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1379     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2064     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0449   |
# |    n_updates        | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1384     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2150     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00416  |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1388     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2248     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0426   |
# |    n_updates        | 536      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1392     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2354     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0395   |
# |    n_updates        | 563      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2453     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00315  |
# |    n_updates        | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2511     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0964   |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2585     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00423  |
# |    n_updates        | 621      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1401     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2644     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0421   |
# |    n_updates        | 635      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1401     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2711     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0377   |
# |    n_updates        | 652      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2783     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.039    |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1408     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2867     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00438  |
# |    n_updates        | 691      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1408     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2923     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 705      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1410     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2994     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0694   |
# |    n_updates        | 723      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1411     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3079     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.177    |
# |    n_updates        | 744      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1411     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3177     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 769      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1415     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3255     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0075   |
# |    n_updates        | 788      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1414     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3325     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.242    |
# |    n_updates        | 806      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1415     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3394     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0103   |
# |    n_updates        | 823      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1417     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3514     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0899   |
# |    n_updates        | 853      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1420     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3603     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0932   |
# |    n_updates        | 875      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1421     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3696     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0384   |
# |    n_updates        | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1421     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3767     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0661   |
# |    n_updates        | 916      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1423     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3874     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.108    |
# |    n_updates        | 943      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1424     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3945     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.189    |
# |    n_updates        | 961      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1425     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4055     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.108    |
# |    n_updates        | 988      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1427     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4182     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00603  |
# |    n_updates        | 1020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1430     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4321     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0821   |
# |    n_updates        | 1055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1430     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4418     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0162   |
# |    n_updates        | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1431     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4542     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0625   |
# |    n_updates        | 1110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1433     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4630     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.164    |
# |    n_updates        | 1132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4744     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0156   |
# |    n_updates        | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4876     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0938   |
# |    n_updates        | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4935     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.175    |
# |    n_updates        | 1208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5082     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0246   |
# |    n_updates        | 1245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5153     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 1263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1435     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5300     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 1299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1435     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5400     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00767  |
# |    n_updates        | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5550     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0768   |
# |    n_updates        | 1362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1436     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5701     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.13     |
# |    n_updates        | 1400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1436     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5793     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0887   |
# |    n_updates        | 1423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.1     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1437     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5964     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0502   |
# |    n_updates        | 1465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1437     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6088     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.227    |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1438     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6338     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.348    |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1438     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6457     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0588   |
# |    n_updates        | 1589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1438     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6517     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.304    |
# |    n_updates        | 1604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1438     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6596     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.369    |
# |    n_updates        | 1623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1439     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6672     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00725  |
# |    n_updates        | 1642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1440     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6805     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.167    |
# |    n_updates        | 1676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 29.9     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1440     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6940     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.141    |
# |    n_updates        | 1709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1440     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7057     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.266    |
# |    n_updates        | 1739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 29.9     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1439     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7171     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.143    |
# |    n_updates        | 1767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1440     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7256     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.152    |
# |    n_updates        | 1788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1440     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7424     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00708  |
# |    n_updates        | 1830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1440     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7519     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.439    |
# |    n_updates        | 1854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7638     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.279    |
# |    n_updates        | 1884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7722     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 1905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7881     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.603    |
# |    n_updates        | 1945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.274    |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.4     |
# |    ep_rew_mean      | 30.4     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8127     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.293    |
# |    n_updates        | 2006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31       |
# |    ep_rew_mean      | 31       |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8254     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.192    |
# |    n_updates        | 2038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1439     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8348     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.379    |
# |    n_updates        | 2061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1438     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8450     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 2087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1438     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8510     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0145   |
# |    n_updates        | 2102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1437     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8597     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.312    |
# |    n_updates        | 2124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1438     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8709     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.209    |
# |    n_updates        | 2152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1439     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8820     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.361    |
# |    n_updates        | 2179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1438     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8901     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 2200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1439     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9098     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.53     |
# |    n_updates        | 2249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1439     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9160     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0194   |
# |    n_updates        | 2264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.5     |
# |    ep_rew_mean      | 27.5     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    time_elapsed     | 428      |
# |    total_timesteps  | 441199   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00315  |
# |    n_updates        | 110274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | 267      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 1028     |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 443116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00373  |
# |    n_updates        | 110753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 279      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 1028     |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 445116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0127   |
# |    n_updates        | 111253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | 295      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 1028     |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 447116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00766  |
# |    n_updates        | 111753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | 309      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 1028     |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 449116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00279  |
# |    n_updates        | 112253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | 325      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 1028     |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 451116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00153  |
# |    n_updates        | 112753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 341      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 1028     |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 453116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00364  |
# |    n_updates        | 113253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 354      |
# |    ep_rew_mean      | 354      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 1028     |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 455116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00554  |
# |    n_updates        | 113753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 369      |
# |    ep_rew_mean      | 369      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 1028     |
# |    time_elapsed     | 444      |
# |    total_timesteps  | 457116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00457  |
# |    n_updates        | 114253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 385      |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 1028     |
# |    time_elapsed     | 446      |
# |    total_timesteps  | 459116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00551  |
# |    n_updates        | 114753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 402      |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 1028     |
# |    time_elapsed     | 448      |
# |    total_timesteps  | 461116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00276  |
# |    n_updates        | 115253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 1028     |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 463116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0105   |
# |    n_updates        | 115753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 1028     |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 465116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00514  |
# |    n_updates        | 116253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 1027     |
# |    time_elapsed     | 454      |
# |    total_timesteps  | 467116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0103   |
# |    n_updates        | 116753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 1027     |
# |    time_elapsed     | 456      |
# |    total_timesteps  | 469116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00728  |
# |    n_updates        | 117253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 481      |
# |    ep_rew_mean      | 481      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 1027     |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 471116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0157   |
# |    n_updates        | 117753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 480      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 1027     |
# |    time_elapsed     | 460      |
# |    total_timesteps  | 472822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00802  |
# |    n_updates        | 118180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 480      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 1027     |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 474822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00179  |
# |    n_updates        | 118680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 483      |
# |    ep_rew_mean      | 483      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 1027     |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 476822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0169   |
# |    n_updates        | 119180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 490      |
# |    ep_rew_mean      | 490      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 1027     |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 478822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00507  |
# |    n_updates        | 119680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 492      |
# |    ep_rew_mean      | 492      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 1027     |
# |    time_elapsed     | 468      |
# |    total_timesteps  | 480822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.03     |
# |    n_updates        | 120180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 493      |
# |    ep_rew_mean      | 493      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 1027     |
# |    time_elapsed     | 469      |
# |    total_timesteps  | 482822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00374  |
# |    n_updates        | 120680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 493      |
# |    ep_rew_mean      | 493      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 1027     |
# |    time_elapsed     | 471      |
# |    total_timesteps  | 484822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0119   |
# |    n_updates        | 121180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 494      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 1027     |
# |    time_elapsed     | 473      |
# |    total_timesteps  | 486822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00161  |
# |    n_updates        | 121680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 496      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 1027     |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 488822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0035   |
# |    n_updates        | 122180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 496      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 1027     |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 490822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00359  |
# |    n_updates        | 122680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 497      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 1026     |
# |    time_elapsed     | 479      |
# |    total_timesteps  | 492822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00701  |
# |    n_updates        | 123180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 497      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 1026     |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 494822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00507  |
# |    n_updates        | 123680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 497      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 1026     |
# |    time_elapsed     | 483      |
# |    total_timesteps  | 496822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00678  |
# |    n_updates        | 124180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 494      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 1026     |
# |    time_elapsed     | 485      |
# |    total_timesteps  | 498548   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00497  |
# |    n_updates        | 124611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 480      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 1026     |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 499116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00353  |
# |    n_updates        | 124753   |
# ----------------------------------

# %%
import gymnasium as gym
from stable_baselines3 import DQN

env = gym.make("CartPole-v1")
model = DQN.load("dqn_cartpole")

obs, info = env.reset()
done = False
score = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    score += reward

print("Score:", score)
env.close()
# Out:
# Score: 500.0

# %%
env = gym.make("CartPole-v1", render_mode="human")
